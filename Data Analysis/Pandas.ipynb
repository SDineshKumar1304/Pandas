# %%
import pandas as pd
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
data=sns.load_dataset('titanic')

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
data.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
data.rename(columns={'sex':'Gender'},inplace=True)

# %%
data.head()
# Out:
#    survived  pclass  Gender   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
data.shape
# Out:
# (891, 15)

# %%
data.describe().T
# Out:
#           count       mean        std   min      25%      50%   75%       max
# survived  891.0   0.383838   0.486592  0.00   0.0000   0.0000   1.0    1.0000
# pclass    891.0   2.308642   0.836071  1.00   2.0000   3.0000   3.0    3.0000
# age       714.0  29.699118  14.526497  0.42  20.1250  28.0000  38.0   80.0000
# sibsp     891.0   0.523008   1.102743  0.00   0.0000   0.0000   1.0    8.0000
# parch     891.0   0.381594   0.806057  0.00   0.0000   0.0000   0.0    6.0000
# fare      891.0  32.204208  49.693429  0.00   7.9104  14.4542  31.0  512.3292

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   Gender       891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
data.head()
# Out:
#    survived  pclass  Gender   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
data['Temp_new']=data['sibsp']*data['fare']

# %%
data.head()
# Out:
#    survived  pclass  Gender   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  Temp_new
# 0    man        True  NaN  Southampton    no  False    7.2500
# 1  woman       False    C    Cherbourg   yes  False   71.2833
# 2  woman       False  NaN  Southampton   yes   True    0.0000
# 3  woman       False    C  Southampton   yes  False   53.1000
# 4    man        True  NaN  Southampton    no   True    0.0000

# %%
data.drop('Temp_new',inplace=True,axis=1)

# %%
data
# Out:
#      survived  pclass  Gender   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
data.set_index('alone',inplace=True)

# %%
data
# Out:
#        survived  pclass  Gender   age  sibsp  parch     fare embarked   class  \
# alone
# False         0       3    male  22.0      1      0   7.2500        S   Third
# False         1       1  female  38.0      1      0  71.2833        C   First
# True          1       3  female  26.0      0      0   7.9250        S   Third
# False         1       1  female  35.0      1      0  53.1000        S   First
# True          0       3    male  35.0      0      0   8.0500        S   Third
# ...         ...     ...     ...   ...    ...    ...      ...      ...     ...
# True          0       2    male  27.0      0      0  13.0000        S  Second
# True          1       1  female  19.0      0      0  30.0000        S   First
# False         0       3  female   NaN      1      2  23.4500        S   Third
# True          1       1    male  26.0      0      0  30.0000        C   First
# True          0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
data.reset_index(inplace=True)

# %%
data
# Out:
#      alone  survived  pclass  Gender   age  sibsp  parch     fare embarked  \
# 0    False         0       3    male  22.0      1      0   7.2500        S
# 1    False         1       1  female  38.0      1      0  71.2833        C
# 2     True         1       3  female  26.0      0      0   7.9250        S
# 3    False         1       1  female  35.0      1      0  53.1000        S
# 4     True         0       3    male  35.0      0      0   8.0500        S
# ..     ...       ...     ...     ...   ...    ...    ...      ...      ...
# 886   True         0       2    male  27.0      0      0  13.0000        S
# 887   True         1       1  female  19.0      0      0  30.0000        S
# 888  False         0       3  female   NaN      1      2  23.4500        S
# 889   True         1       1    male  26.0      0      0  30.0000        C
# 890   True         0       3    male  32.0      0      0   7.7500        Q
#
#       class    who  adult_male deck  embark_town alive
# ...

# %%
data['embark_town'][:]
# Out:
# 0      Southampton
# 1        Cherbourg
# 2      Southampton
# 3      Southampton
# 4      Southampton
#           ...
# 886    Southampton
# 887    Southampton
# 888    Southampton
# 889      Cherbourg
# 890     Queenstown
# Name: embark_town, Length: 891, dtype: object

# %%
data.loc[90:,['alone','survived','pclass']]
# Out:
#      alone  survived  pclass
# 90    True         0       3
# 91    True         0       3
# 92   False         0       1
# 93   False         0       3
# 94    True         0       3
# ..     ...       ...     ...
# 886   True         0       2
# 887   True         1       1
# 888  False         0       3
# 889   True         1       1
# 890   True         0       3
#
# [801 rows x 3 columns]

# %%
data.iloc[88::,4:8]
# Out:
#       age  sibsp  parch      fare
# 88   23.0      3      2  263.0000
# 89   24.0      0      0    8.0500
# 90   29.0      0      0    8.0500
# 91   20.0      0      0    7.8542
# 92   46.0      1      0   61.1750
# ..    ...    ...    ...       ...
# 886  27.0      0      0   13.0000
# 887  19.0      0      0   30.0000
# 888   NaN      1      2   23.4500
# 889  26.0      0      0   30.0000
# 890  32.0      0      0    7.7500
#
# [803 rows x 4 columns]

# %%
data.drop(890,axis=0,inplace=True)

# %%
data.shape
# Out:
# (890, 15)

# %%
data[(data['Gender']=='male') & (data['age']>36)]
# Out:
#      alone  survived  pclass Gender   age  sibsp  parch     fare embarked  \
# 6     True         0       1   male  54.0      0      0  51.8625        S
# 13   False         0       3   male  39.0      1      5  31.2750        S
# 30    True         0       1   male  40.0      0      0  27.7208        C
# 33    True         0       2   male  66.0      0      0  10.5000        S
# 35   False         0       1   male  42.0      1      0  52.0000        S
# ..     ...       ...     ...    ...   ...    ...    ...      ...      ...
# 845   True         0       3   male  42.0      0      0   7.5500        S
# 851   True         0       3   male  74.0      0      0   7.7750        S
# 857   True         1       1   male  51.0      0      0  26.5500        S
# 860  False         0       3   male  41.0      2      0  14.1083        S
# 873   True         0       3   male  47.0      0      0   9.0000        S
#
#       class  who  adult_male deck  embark_town alive
# ...

# %%
data[((data['Gender']=='male')|(data['Gender']=='female'))& (data['alive']=='yes')]
# Out:
#      alone  survived  pclass  Gender   age  sibsp  parch     fare embarked  \
# 1    False         1       1  female  38.0      1      0  71.2833        C
# 2     True         1       3  female  26.0      0      0   7.9250        S
# 3    False         1       1  female  35.0      1      0  53.1000        S
# 8    False         1       3  female  27.0      0      2  11.1333        S
# 9    False         1       2  female  14.0      1      0  30.0708        C
# ..     ...       ...     ...     ...   ...    ...    ...      ...      ...
# 875   True         1       3  female  15.0      0      0   7.2250        C
# 879  False         1       1  female  56.0      0      1  83.1583        C
# 880  False         1       2  female  25.0      0      1  26.0000        S
# 887   True         1       1  female  19.0      0      0  30.0000        S
# 889   True         1       1    male  26.0      0      0  30.0000        C
#
#       class    who  adult_male deck  embark_town alive
# ...

# %%
data[(data['Gender']).isin(['male','female'])]
# Out:
#      alone  survived  pclass  Gender   age  sibsp  parch     fare embarked  \
# 0    False         0       3    male  22.0      1      0   7.2500        S
# 1    False         1       1  female  38.0      1      0  71.2833        C
# 2     True         1       3  female  26.0      0      0   7.9250        S
# 3    False         1       1  female  35.0      1      0  53.1000        S
# 4     True         0       3    male  35.0      0      0   8.0500        S
# ..     ...       ...     ...     ...   ...    ...    ...      ...      ...
# 885  False         0       3  female  39.0      0      5  29.1250        Q
# 886   True         0       2    male  27.0      0      0  13.0000        S
# 887   True         1       1  female  19.0      0      0  30.0000        S
# 888  False         0       3  female   NaN      1      2  23.4500        S
# 889   True         1       1    male  26.0      0      0  30.0000        C
#
#       class    who  adult_male deck  embark_town alive
# ...

# %%
def fun(x):
  return x.title()

# %%
fun('make')
# Out:
# 'Make'

# %%
data['Gender']=data['Gender'].apply(fun)

# %%
data
# Out:
#      alone  survived  pclass  Gender   age  sibsp  parch     fare embarked  \
# 0    False         0       3    Male  22.0      1      0   7.2500        S
# 1    False         1       1  Female  38.0      1      0  71.2833        C
# 2     True         1       3  Female  26.0      0      0   7.9250        S
# 3    False         1       1  Female  35.0      1      0  53.1000        S
# 4     True         0       3    Male  35.0      0      0   8.0500        S
# ..     ...       ...     ...     ...   ...    ...    ...      ...      ...
# 885  False         0       3  Female  39.0      0      5  29.1250        Q
# 886   True         0       2    Male  27.0      0      0  13.0000        S
# 887   True         1       1  Female  19.0      0      0  30.0000        S
# 888  False         0       3  Female   NaN      1      2  23.4500        S
# 889   True         1       1    Male  26.0      0      0  30.0000        C
#
#       class    who  adult_male deck  embark_town alive
# ...

# %%
data['Gender']==data['Gender'].apply(fun)
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 885    True
# 886    True
# 887    True
# 888    True
# 889    True
# Name: Gender, Length: 890, dtype: bool

# %%
data.columns=data.columns.map(fun)

# %%
data
# Out:
#      Alone  Survived  Pclass  Gender   Age  Sibsp  Parch     Fare Embarked  \
# 0    False         0       3    Male  22.0      1      0   7.2500        S
# 1    False         1       1  Female  38.0      1      0  71.2833        C
# 2     True         1       3  Female  26.0      0      0   7.9250        S
# 3    False         1       1  Female  35.0      1      0  53.1000        S
# 4     True         0       3    Male  35.0      0      0   8.0500        S
# ..     ...       ...     ...     ...   ...    ...    ...      ...      ...
# 885  False         0       3  Female  39.0      0      5  29.1250        Q
# 886   True         0       2    Male  27.0      0      0  13.0000        S
# 887   True         1       1  Female  19.0      0      0  30.0000        S
# 888  False         0       3  Female   NaN      1      2  23.4500        S
# 889   True         1       1    Male  26.0      0      0  30.0000        C
#
#       Class    Who  Adult_Male Deck  Embark_Town Alive
# ...

# %%
data['Fare']=data['Fare'].apply(lambda x: int(x))

# %%
data
# Out:
#      Alone  Survived  Pclass  Gender   Age  Sibsp  Parch  Fare Embarked  \
# 0    False         0       3    Male  22.0      1      0     7        S
# 1    False         1       1  Female  38.0      1      0    71        C
# 2     True         1       3  Female  26.0      0      0     7        S
# 3    False         1       1  Female  35.0      1      0    53        S
# 4     True         0       3    Male  35.0      0      0     8        S
# ..     ...       ...     ...     ...   ...    ...    ...   ...      ...
# 885  False         0       3  Female  39.0      0      5    29        Q
# 886   True         0       2    Male  27.0      0      0    13        S
# 887   True         1       1  Female  19.0      0      0    30        S
# 888  False         0       3  Female   NaN      1      2    23        S
# 889   True         1       1    Male  26.0      0      0    30        C
#
#       Class    Who  Adult_Male Deck  Embark_Town Alive
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 890 entries, 0 to 889
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Alone        890 non-null    bool
#  1   Survived     890 non-null    int64
#  2   Pclass       890 non-null    int64
#  3   Gender       890 non-null    object
#  4   Age          713 non-null    float64
#  5   Sibsp        890 non-null    int64
#  6   Parch        890 non-null    int64
#  7   Fare         890 non-null    int64
#  8   Embarked     888 non-null    object
#  9   Class        890 non-null    category
#  10  Who          890 non-null    object
#  11  Adult_Male   890 non-null    bool
#  12  Deck         203 non-null    category
#  13  Embark_Town  888 non-null    object
#  14  Alive        890 non-null    object
# dtypes: bool(2), category(2), float64(1), int64(5), object(5)
# memory usage: 80.6+ KB

# %%
data.head()
# Out:
#    Alone  Survived  Pclass  Gender   Age  Sibsp  Parch  Fare Embarked  Class  \
# 0  False         0       3    Male  22.0      1      0     7        S  Third
# 1  False         1       1  Female  38.0      1      0    71        C  First
# 2   True         1       3  Female  26.0      0      0     7        S  Third
# 3  False         1       1  Female  35.0      1      0    53        S  First
# 4   True         0       3    Male  35.0      0      0     8        S  Third
#
#      Who  Adult_Male Deck  Embark_Town Alive
# 0    man        True  NaN  Southampton    no
# 1  woman       False    C    Cherbourg   yes
# 2  woman       False  NaN  Southampton   yes
# 3  woman       False    C  Southampton   yes
# 4    man        True  NaN  Southampton    no

# %%
data.sort_values(by='Fare')
# Out:
#      Alone  Survived  Pclass  Gender   Age  Sibsp  Parch  Fare Embarked  \
# 413   True         0       2    Male   NaN      0      0     0        S
# 481   True         0       2    Male   NaN      0      0     0        S
# 815   True         0       1    Male   NaN      0      0     0        S
# 302   True         0       3    Male  19.0      0      0     0        S
# 271   True         1       3    Male  25.0      0      0     0        S
# ..     ...       ...     ...     ...   ...    ...    ...   ...      ...
# 438  False         0       1    Male  64.0      1      4   263        S
# 88   False         1       1  Female  23.0      3      2   263        S
# 258   True         1       1  Female  35.0      0      0   512        C
# 737   True         1       1    Male  35.0      0      0   512        C
# 679  False         1       1    Male  36.0      0      1   512        C
#
#       Class    Who  Adult_Male Deck  Embark_Town Alive
# ...

# %%
data.sort_values(by='Fare',ascending=False)
# Out:
#      Alone  Survived  Pclass  Gender   Age  Sibsp  Parch  Fare Embarked  \
# 679  False         1       1    Male  36.0      0      1   512        C
# 258   True         1       1  Female  35.0      0      0   512        C
# 737   True         1       1    Male  35.0      0      0   512        C
# 88   False         1       1  Female  23.0      3      2   263        S
# 438  False         0       1    Male  64.0      1      4   263        S
# ..     ...       ...     ...     ...   ...    ...    ...   ...      ...
# 302   True         0       3    Male  19.0      0      0     0        S
# 481   True         0       2    Male   NaN      0      0     0        S
# 674   True         0       2    Male   NaN      0      0     0        S
# 806   True         0       1    Male  39.0      0      0     0        S
# 822   True         0       1    Male  38.0      0      0     0        S
#
#       Class    Who  Adult_Male Deck  Embark_Town Alive
# ...

# %%
data['Fare'].max()
# Out:
# 512

# %%
data['Fare'].idxmax()
# Out:
# 258

# %%
data['Fare'].min()
# Out:
# 0

# %%
data['Fare'].idxmin()
# Out:
# 179

# %%
data.value_counts(['Gender','Alive'])
# Out:
# Gender  Alive
# Male    no       467
# Female  yes      233
# Male    yes      109
# Female  no        81
# dtype: int64

# %%
data[['Gender','Alive']].value_counts(sort=False)
# Out:
# Gender  Alive
# Female  no        81
#         yes      233
# Male    no       467
#         yes      109
# dtype: int64

# %%
data['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
data.nunique()
# Out:
# Alone           2
# Survived        2
# Pclass          3
# Gender          2
# Age            88
# Sibsp           7
# Parch           7
# Fare           91
# Embarked        3
# Class           3
# Who             3
# Adult_Male      2
# Deck            7
# Embark_Town     3
# Alive           2
# dtype: int64

# %%
data['Gender'].replace(['Male','Female'],['M','F'],inplace=True)

# %%
data.head()
# Out:
#    Alone  Survived  Pclass Gender   Age  Sibsp  Parch  Fare Embarked  Class  \
# 0  False         0       3      M  22.0      1      0     7        S  Third
# 1  False         1       1      F  38.0      1      0    71        C  First
# 2   True         1       3      F  26.0      0      0     7        S  Third
# 3  False         1       1      F  35.0      1      0    53        S  First
# 4   True         0       3      M  35.0      0      0     8        S  Third
#
#      Who  Adult_Male Deck  Embark_Town Alive
# 0    man        True  NaN  Southampton    no
# 1  woman       False    C    Cherbourg   yes
# 2  woman       False  NaN  Southampton   yes
# 3  woman       False    C  Southampton   yes
# 4    man        True  NaN  Southampton    no

# %%
data['Gender'].replace(['M','F'],['Male','Female'],inplace=True)

# %%
data.head()
# Out:
#    Alone  Survived  Pclass  Gender   Age  Sibsp  Parch  Fare Embarked  Class  \
# 0  False         0       3    Male  22.0      1      0     7        S  Third
# 1  False         1       1  Female  38.0      1      0    71        C  First
# 2   True         1       3  Female  26.0      0      0     7        S  Third
# 3  False         1       1  Female  35.0      1      0    53        S  First
# 4   True         0       3    Male  35.0      0      0     8        S  Third
#
#      Who  Adult_Male Deck  Embark_Town Alive
# 0    man        True  NaN  Southampton    no
# 1  woman       False    C    Cherbourg   yes
# 2  woman       False  NaN  Southampton   yes
# 3  woman       False    C  Southampton   yes
# 4    man        True  NaN  Southampton    no

# %%
data.sample(10)
# Out:
#      Alone  Survived  Pclass  Gender   Age  Sibsp  Parch  Fare Embarked  \
# 213   True         0       2    Male  30.0      0      0    13        S
# 553   True         1       3    Male  22.0      0      0     7        C
# 319  False         1       1  Female  40.0      1      1   134        C
# 502   True         0       3  Female   NaN      0      0     7        Q
# 527   True         0       1    Male   NaN      0      0   221        S
# 194   True         1       1  Female  44.0      0      0    27        C
# 434  False         0       1    Male  50.0      1      0    55        S
# 848  False         0       2    Male  28.0      0      1    33        S
# 495   True         0       3    Male   NaN      0      0    14        C
# 596   True         1       2  Female   NaN      0      0    33        S
#
#       Class    Who  Adult_Male Deck  Embark_Town Alive
# 213  Second    man        True  NaN  Southampton    no
# 553   Third    man        True  NaN    Cherbourg   yes
# ...

# %%
data.Who.unique()
# Out:
# array(['man', 'woman', 'child'], dtype=object)

# %%
data['Who'] = data['Who'].map({'man': "M", 'women': "F", 'child': "C"})

# %%
data.head()
# Out:
#    Alone  Survived  Pclass  Gender   Age  Sibsp  Parch  Fare Embarked  Class  \
# 0  False         0       3    Male  22.0      1      0     7        S  Third
# 1  False         1       1  Female  38.0      1      0    71        C  First
# 2   True         1       3  Female  26.0      0      0     7        S  Third
# 3  False         1       1  Female  35.0      1      0    53        S  First
# 4   True         0       3    Male  35.0      0      0     8        S  Third
#
#    Who  Adult_Male Deck  Embark_Town Alive
# 0    M        True  NaN  Southampton    no
# 1  NaN       False    C    Cherbourg   yes
# 2  NaN       False  NaN  Southampton   yes
# 3  NaN       False    C  Southampton   yes
# 4    M        True  NaN  Southampton    no

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 885    False
# 886     True
# 887    False
# 888    False
# 889    False
# Length: 890, dtype: bool

# %%
data.drop_duplicates()
# Out:
#      Alone  Survived  Pclass  Gender   Age  Sibsp  Parch  Fare Embarked  \
# 0    False         0       3    Male  22.0      1      0     7        S
# 1    False         1       1  Female  38.0      1      0    71        C
# 2     True         1       3  Female  26.0      0      0     7        S
# 3    False         1       1  Female  35.0      1      0    53        S
# 4     True         0       3    Male  35.0      0      0     8        S
# ..     ...       ...     ...     ...   ...    ...    ...   ...      ...
# 883   True         0       2    Male  28.0      0      0    10        S
# 885  False         0       3  Female  39.0      0      5    29        Q
# 887   True         1       1  Female  19.0      0      0    30        S
# 888  False         0       3  Female   NaN      1      2    23        S
# 889   True         1       1    Male  26.0      0      0    30        C
#
#       Class  Who  Adult_Male Deck  Embark_Town Alive
# ...

# %%
data.nlargest(10,'Fare')
# Out:
#      Alone  Survived  Pclass  Gender   Age  Sibsp  Parch  Fare Embarked  \
# 258   True         1       1  Female  35.0      0      0   512        C
# 679  False         1       1    Male  36.0      0      1   512        C
# 737   True         1       1    Male  35.0      0      0   512        C
# 27   False         0       1    Male  19.0      3      2   263        S
# 88   False         1       1  Female  23.0      3      2   263        S
# 341  False         1       1  Female  24.0      3      2   263        S
# 438  False         0       1    Male  64.0      1      4   263        S
# 311  False         1       1  Female  18.0      2      2   262        C
# 742  False         1       1  Female  21.0      2      2   262        C
# 118  False         0       1    Male  24.0      0      1   247        C
#
#      Class  Who  Adult_Male Deck  Embark_Town Alive
# 258  First  NaN       False  NaN    Cherbourg   yes
# 679  First    M        True    B    Cherbourg   yes
# ...

# %%
data.nsmallest(10,'Fare')
# Out:
#      Alone  Survived  Pclass Gender   Age  Sibsp  Parch  Fare Embarked  \
# 179   True         0       3   Male  36.0      0      0     0        S
# 263   True         0       1   Male  40.0      0      0     0        S
# 271   True         1       3   Male  25.0      0      0     0        S
# 277   True         0       2   Male   NaN      0      0     0        S
# 302   True         0       3   Male  19.0      0      0     0        S
# 413   True         0       2   Male   NaN      0      0     0        S
# 466   True         0       2   Male   NaN      0      0     0        S
# 481   True         0       2   Male   NaN      0      0     0        S
# 597   True         0       3   Male  49.0      0      0     0        S
# 633   True         0       1   Male   NaN      0      0     0        S
#
#       Class Who  Adult_Male Deck  Embark_Town Alive
# 179   Third   M        True  NaN  Southampton    no
# 263   First   M        True    B  Southampton    no
# ...

# %%
data.sample(frac=0.01)
# Out:
#      Alone  Survived  Pclass  Gender    Age  Sibsp  Parch  Fare Embarked  \
# 520   True         1       1  Female  30.00      0      0    93        S
# 668   True         0       3    Male  43.00      0      0     8        S
# 819  False         0       3    Male  10.00      3      2    27        S
# 755  False         1       2    Male   0.67      1      1    14        S
# 242   True         0       2    Male  29.00      0      0    10        S
# 134   True         0       2    Male  25.00      0      0    13        S
# 384   True         0       3    Male    NaN      0      0     7        S
# 768  False         0       3    Male    NaN      1      0    24        Q
# 885  False         0       3  Female  39.00      0      5    29        Q
#
#       Class  Who  Adult_Male Deck  Embark_Town Alive
# 520   First  NaN       False    B  Southampton   yes
# 668   Third    M        True  NaN  Southampton    no
# 819   Third    C       False  NaN  Southampton    no
# ...

# %%
data.isnull().sum()
# Out:
# Alone            0
# Survived         0
# Pclass           0
# Gender           0
# Age            177
# Sibsp            0
# Parch            0
# Fare             0
# Embarked         2
# Class            0
# Who            271
# Adult_Male       0
# Deck           687
# Embark_Town      2
# Alive            0
# dtype: int64

# %%
(data.isnull().sum() * 100 / len(data)).round(2)
# Out:
# Alone           0.00
# Survived        0.00
# Pclass          0.00
# Gender          0.00
# Age            19.89
# Sibsp           0.00
# Parch           0.00
# Fare            0.00
# Embarked        0.22
# Class           0.00
# Who            30.45
# Adult_Male      0.00
# Deck           77.19
# Embark_Town     0.22
# Alive           0.00
# dtype: float64

# %%
(data.notnull().sum() * 100 / len(data)).round(2)
# Out:
# Alone          100.00
# Survived       100.00
# Pclass         100.00
# Gender         100.00
# Age             80.11
# Sibsp          100.00
# Parch          100.00
# Fare           100.00
# Embarked        99.78
# Class          100.00
# Who             69.55
# Adult_Male     100.00
# Deck            22.81
# Embark_Town     99.78
# Alive          100.00
# dtype: float64

# %%
mean_age=data['Age'].mean()

# %%
mean_age
# Out:
# 29.69589060308555

# %%
data['Age'].fillna(mean_age).isnull().sum()
# Out:
# 0

# %%
data['Age'].mode()
# Out:
# 0    24.0
# Name: Age, dtype: float64

# %%
data['Age'].fillna(24,inplace=True)

# %%
data['Age'].isnull().sum()
# Out:
# 0
